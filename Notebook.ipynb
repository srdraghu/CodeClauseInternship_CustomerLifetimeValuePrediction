# %% [markdown]
# Customer Lifetime Value Prediction

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.preprocessing import *
from sklearn.linear_model import *
from sklearn.model_selection import train_test_split
from sklearn.metrics import *

# %%
data = pd.read_csv('Dataset.csv')
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
data.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
print(data['State'].value_counts())
print(data['Gender'].value_counts())
data['EmploymentStatus'].value_counts()
# Out:
# State
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: count, dtype: int64
# Gender
# F    4658
# M    4476
# Name: count, dtype: int64
# EmploymentStatus
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: count, dtype: int64

# %% [markdown]
# Data preprocessing and Modeling

# %%
data.isnull().sum()
# Out:
# Customer                         0
# State                            0
# Customer Lifetime Value          0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
data['Effective To Date']=pd.to_datetime(data['Effective To Date'])
data['Effective To Date'].to_timestamp
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13176\1575115014.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Effective To Date']=pd.to_datetime(data['Effective To Date'])
# <bound method Series.to_timestamp of 0      2011-02-24
# 1      2011-01-31
# 2      2011-02-19
# 3      2011-01-20
# 4      2011-02-03
#           ...
# 9129   2011-02-10
# 9130   2011-02-12
# 9131   2011-02-06
# 9132   2011-02-03
# 9133   2011-02-14
# Name: Effective To Date, Length: 9134, dtype: datetime64[ns]>

# %%
lb=LabelEncoder()
data['Customer']=lb.fit_transform(data['Customer'])
data['State']=lb.fit_transform(data['State'])
data['Response']=lb.fit_transform(data['Response'])
data['Coverage']=lb.fit_transform(data['Coverage'])
data['Education']=lb.fit_transform(data['Education'])
data['EmploymentStatus']=lb.fit_transform(data['EmploymentStatus'])
data['Gender']=lb.fit_transform(data['Gender'])
data['Policy Type']=lb.fit_transform(data['Policy Type'])
data['Policy']=lb.fit_transform(data['Policy'])
data['Renew Offer Type']=lb.fit_transform(data['Renew Offer Type'])
data['Vehicle Class']=lb.fit_transform(data['Vehicle Class'])
data['Vehicle Size']=lb.fit_transform(data['Vehicle Size'])
data['Sales Channel']=lb.fit_transform(data['Sales Channel'])
data['Marital Status']=lb.fit_transform(data['Marital Status'])
data['Location Code']=lb.fit_transform(data['Location Code'])

# %%
correlation_matrix = data.corr()
correlation_with_clv = correlation_matrix["Customer Lifetime Value"].sort_values(ascending=False)
print(correlation_with_clv)
# Out:
# Customer Lifetime Value          1.000000
# Monthly Premium Auto             0.396262
# Total Claim Amount               0.226451
# Coverage                         0.168040
# Vehicle Class                    0.082307
# Education                        0.026038
# Income                           0.024366
# Number of Policies               0.021955
# Policy Type                      0.020011
# Vehicle Size                     0.017098
# Policy                           0.015217
# Months Since Last Claim          0.011517
# Months Since Policy Inception    0.009418
# State                            0.008778
# Location Code                    0.004854
# Sales Channel                   -0.003941
# Effective To Date               -0.004844
# Response                        -0.008930
# Gender                          -0.013610
# Marital Status                  -0.026003
# Customer                        -0.028605
# EmploymentStatus                -0.034846
# ...

# %%
top_features = correlation_with_clv.index[1:11]
print("Top features correlated with SalePrice:\n", top_features)
# Out:
# Top features correlated with SalePrice:
#  Index(['Monthly Premium Auto', 'Total Claim Amount', 'Coverage',
#        'Vehicle Class', 'Education', 'Income', 'Number of Policies',
#        'Policy Type', 'Vehicle Size', 'Policy'],
#       dtype='object')

# %%
new_data = data[top_features]
new_data
# Out:
#       Monthly Premium Auto  Total Claim Amount  Coverage  Vehicle Class  \
# 0                       69          384.811147         0              5
# 1                       94         1131.464935         1              0
# 2                      108          566.472247         2              5
# 3                      106          529.881344         0              3
# 4                       73          138.130879         0              0
# ...                    ...                 ...       ...            ...
# 9129                    73          198.234764         0              0
# 9130                    79          379.200000         1              0
# 9131                    85          790.784983         1              0
# 9132                    96          691.200000         1              0
# 9133                    77          369.600000         1              5
#
#       Education  Income  Number of Policies  Policy Type  Vehicle Size  Policy
# ...

# %%
new_data['Customer Lifetime Value']=data['Customer Lifetime Value']
new_data
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13176\1816714325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['Customer Lifetime Value']=data['Customer Lifetime Value']
#       Monthly Premium Auto  Total Claim Amount  Coverage  Vehicle Class  \
# 0                       69          384.811147         0              5
# 1                       94         1131.464935         1              0
# 2                      108          566.472247         2              5
# 3                      106          529.881344         0              3
# 4                       73          138.130879         0              0
# ...                    ...                 ...       ...            ...
# ...

# %%
print(new_data['Customer Lifetime Value'].skew())
sns.distplot(new_data['Customer Lifetime Value'])
# Out:
# 3.0322802599299847
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13176\2603331853.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_data['Customer Lifetime Value'])
# <Axes: xlabel='Customer Lifetime Value', ylabel='Density'>

# %%
new_data['Customer Lifetime Value']=np.log(new_data['Customer Lifetime Value'])
sns.distplot(new_data)
print(new_data['Customer Lifetime Value'].skew())
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13176\4227128715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['Customer Lifetime Value']=np.log(new_data['Customer Lifetime Value'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13176\4227128715.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_data)
# 0.31081824329150964

# %%
new_data['Total Claim Amount'].skew()
new_data['Total Claim Amount']=np.log(new_data['Total Claim Amount'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13176\333915174.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['Total Claim Amount']=np.log(new_data['Total Claim Amount'])

# %%
new_data.index.is_unique
# Out:
# True

# %%
X=new_data.drop(columns='Customer Lifetime Value',axis=1)
Y=new_data['Customer Lifetime Value']

xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.3,random_state=0)
print(xtrain.shape)
print(xtest.shape)
# Out:
# (6393, 10)
# (2741, 10)

# %%
model=LinearRegression()
model.fit(xtrain,ytrain)
print("Model :",model)

prediction = model.predict(xtest)
print("Predicted Values :",prediction)

acc = r2_score(ytest,prediction)*100
mae=mean_absolute_error(ytest,prediction)
mse=mean_squared_error(ytest,prediction)
# Out:
# Model : LinearRegression()
# Predicted Values : [0.77228594 0.75336155 0.79616085 ... 0.77256676 0.76062187 0.75536794]

# %%
print(f"R2 score : {acc:.2f}")
print(f"Mean Absolute error {mae:.2f}")
print(f"Mean Squared error {mse:.2f}")
# Out:
# R2 score : 24.00
# Mean Absolute error 0.02
# Mean Squared error 0.00
